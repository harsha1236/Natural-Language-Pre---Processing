# %% [markdown]
# <a href="https://colab.research.google.com/github/harsha1236/Natural-Language-Pre---Processing/blob/main/natural_language_pre_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> l
#
# Packages:
#   [ ] abc................. Australian Broadcasting Commission 2006
#   [ ] alpino.............. Alpino Dutch Treebank
#   [ ] averaged_perceptron_tagger Averaged Perceptron Tagger
#   [ ] averaged_perceptron_tagger_eng Averaged Perceptron Tagger (JSON)
#   [ ] averaged_perceptron_tagger_ru Averaged Perceptron Tagger (Russian)
#   [ ] averaged_perceptron_tagger_rus Averaged Perceptron Tagger (Russian)
#   [ ] basque_grammars..... Grammars for Basque
#   [ ] bcp47............... BCP-47 Language Tags
#   [ ] biocreative_ppi..... BioCreAtIvE (Critical Assessment of Information
#                            Extraction Systems in Biology)
#   [ ] bllip_wsj_no_aux.... BLLIP Parser: WSJ Model
#   [ ] book_grammars....... Grammars from NLTK Book
#   [ ] brown............... Brown Corpus
#   [ ] brown_tei........... Brown Corpus (TEI XML Version)
#   [ ] cess_cat............ CESS-CAT Treebank
#   [ ] cess_esp............ CESS-ESP Treebank
#   [ ] chat80.............. Chat-80 Data Files
#   [ ] city_database....... City Database
#   [ ] cmudict............. The Carnegie Mellon Pronouncing Dictionary (0.6)
#   [ ] comparative_sentences Comparative Sentence Dataset
# Hit Enter to continue: Q
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> Q
# True

# %%
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
nltk.download('genesis')
# Out:
# [nltk_data] Downloading package genesis to /root/nltk_data...
# [nltk_data]   Unzipping corpora/genesis.zip.
# True

# %%
moby_dick = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
print(moby_dick)
# Out:
# ['[', 'Moby', 'Dick', 'by', 'Herman', 'Melville', ...]

# %%
whit_man =nltk.corpus.gutenberg.words('whitman-leaves.txt')

# %%
print(len(whit_man))
# Out:
# 154883

# %% [markdown]
# Removing punctuations, accent marks, special symbols and diacritics

# %%
import re
def remove_regex(input_pattern,input_text):
  url = re.finditer(input_pattern,input_text)
  for i in url:
    input_text = re.sub(i.group(),'',input_text)
  return input_text
regex_pattern = "#[\\w]*"

remove_regex( regex_pattern,"remove this #hashtag from my given string object to ensure no #repeatperformance")
# Out:
# 'remove this  from my given string object to ensure no '

# %%
my_dict = {83:80}
text = "Hello Sam"
text.translate(my_dict)
# Out:
# 'Hello Pam'

# %%
import string
table_map = str.maketrans("","",string.punctuation)

# %%
s = "India is going to win the match unless there is rains, or some unexpected event."
s.translate(str.maketrans("","",string.punctuation))
# Out:
# 'India is going to win the match unless there is rains or some unexpected event'

# %% [markdown]
# REMOVE WHITE SPACES

# %%
input_str = " \ta string example\t "
print (input_str)
input_str = input_str.strip()
input_str
# Out:
#  	a string example
# 'a string example'

# %%
print(input_str.split())
# Out:
# ['a', 'string', 'example']

# %% [markdown]
# Remove or Replace Numbers

# %%
regex_pattern = "[0-9]+"
input_txt = '1 banana 23 apple 456 oranges'

remove_regex(input_txt, regex_pattern)
# Out:
# '[0-9]+'

# %%
! pip install num2words
# Out:
# Collecting num2words
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting docopt>=0.6.2 (from num2words)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 3.6 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=0bf223e26d5270b718954a569dc335344370b46f26259870aad00579deab1045
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.14

# %%
from num2words import num2words
num2words(23429875)
# Out:
# 'twenty-three million, four hundred and twenty-nine thousand, eight hundred and seventy-five'

# %%
import re
input_str = "Box A contains 3 red and 5 white balls, while Box B contains 4 red and 2 blue balls."
out = ' '.join([num2words(i) if i.isdigit() else i for i in input_str.split()])
out
# Out:
# 'Box A contains three red and five white balls, while Box B contains four red and two blue balls.'

# %%
output = re.sub(r"\d+", lambda x:num2words(int(x.group())), input_str)

output
# Out:
# 'Box A contains three red and five white balls, while Box B contains four red and two blue balls.'

# %% [markdown]
# Convert Case

# %%
input_str = "The 5 biggest countries by population in 2017 are China, India, United States, Indonesia, and Brazil."
input_str = input_str.lower()
print(input_str)
# Out:
# the 5 biggest countries by population in 2017 are china, india, united states, indonesia, and brazil.

# %% [markdown]
# Tokenization
#
# Tokenization is the process of splitting the given text into smaller pieces called tokens. Words, numbers, punctuation marks, and others can be considered as tokens.

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
input_str = "NLTK is a leading platform for building Python programs to work with human language data."
from nltk.tokenize import word_tokenize
tokens = word_tokenize(input_str)
print(tokens)
# Out:
# ['NLTK', 'is', 'a', 'leading', 'platform', 'for', 'building', 'Python', 'programs', 'to', 'work', 'with', 'human', 'language', 'data', '.']

# %% [markdown]
# Remove stop words
#
# Stop words are the most common words in a language like “the”, “a”, “on”, “is”, “all”. These words do not carry important meaning and are usually removed from texts for NLP

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'his', 'what', 'through', 'wouldn', "you've", "he's", 'couldn', 'not', "it's", 'why', "shouldn't", 'then', "she'd", "we'll", 'while', 'a', 'against', 'only', "he'd", 'be', 'themselves', 'the', 'her', 'all', "it'll", 'there', 'now', "they'd", 'their', 'once', "you're", 'hasn', 'didn', 'himself', 'yourselves', 'are', 'most', 'should', 'hadn', 'just', 'by', 'that', 'this', 'll', 'no', 'during', 'of', 'if', 'its', 'we', 'an', 'to', 's', 're', 't', 'have', 've', "we'd", 'or', 'haven', 'up', "isn't", "should've", 'can', 'as', 'they', "wasn't", 'from', 'do', 'isn', 'under', 'ours', 'i', "won't", 'each', 'and', 'too', 'it', 'on', "mightn't", 'you', 'down', 'them', 'theirs', 'am', 'shan', 'does', 'in', 'with', "mustn't", 'above', "weren't", 'before', 'myself', 'few', 'herself', "needn't", 'who', 'having', "doesn't", 'doing', 'than', 'other', 'don', 'being', 'which', 'y', "don't", 'off', 'whom', 'but', 'how', 'did', 'out', 'ma', 'because', "they'll", 'yours', "you'll", 'will', "they're", "wouldn't", "shan't", 'has', 'between', 'very', 'him', 'were', 'some', 'hers', 'own', "they've", "i'll", "couldn't", 'itself', 'further', 'm', 'my', 'same', "you'd", "it'd", 'your', "didn't", 'yourself', 'here', 'ourselves', 'wasn', 'nor', 'for', 'until', 'into', 'o', 'been', 'won', "that'll", 'shouldn', 'had', "haven't", 'ain', 'aren', "she's", 'so', 'any', 'our', 'over', 'mightn', 'below', 'needn', 'me', 'these', "hasn't", "i'd", 'both', 'again', "hadn't", "she'll", "we've", 'where', 'was', 'd', "we're", 'mustn', 'more', "i've", "he'll", 'she', 'he', 'is', 'weren', 'such', 'those', 'doesn', "aren't", 'when', "i'm", 'after', 'about', 'at'}

# %%
input_str = "All work and no play makes jack a dull boy. Its good to go out and have fun at times."
token = word_tokenize(input_str)
out =' '.join([i for i in token if i not in stop_words])
out
# Out:
# 'All work play makes jack dull boy . Its good go fun times .'

# %%
from sklearn.feature_extraction import _stop_words
print (_stop_words)
# Out:
# <module 'sklearn.feature_extraction._stop_words' from '/usr/local/lib/python3.12/dist-packages/sklearn/feature_extraction/_stop_words.py'>

# %% [markdown]
# Stemming
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
stemmer= PorterStemmer()
input_str="There are several types of stemming algorithms for Natural languages"
token = word_tokenize(input_str)
stop = [i for i in token if i not in stop_words]
stop
for i in stop:
  print(stemmer.stem(i))
# Out:
# there
# sever
# type
# stem
# algorithm
# natur
# languag

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
stemmer2 = SnowballStemmer("english", ignore_stopwords=True)
print(stemmer.stem("having"))
print(stemmer2.stem("having"))

print(SnowballStemmer("english").stem("generously"))

print(SnowballStemmer("porter").stem("generously"))
# Out:
# have
# having
# generous
# gener

# %% [markdown]
# Lemmatizer
# The goal of both stemming and lemmatization is to reduce inflectional forms and sometimes derivationally related forms of a word to a common base form.
#
# However, the two words differ in their flavor. Stemming usually refers to a crude heuristic process that chops off the ends of words in the hope of achieving this goal correctly most of the time, and often includes the removal of derivational affixes.
#
# Lemmatization usually refers to doing things properly with the use of a vocabulary and morphological analysis of words, normally aiming to remove inflectional endings only and to return the base or dictionary form of a word, which is known as the lemma .

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import nltk
lemma  = nltk.wordnet.WordNetLemmatizer()
lemma.lemmatize('played', pos="v")
# Out:
# 'play'

# %%
lemma.lemmatize('meeting', pos="v")
# Out:
# 'meet'

# %%
lemma.lemmatize('players', pos="n")
# Out:
# 'player'

# %%
input_str = "English fans were really rude and disrespectful to Italian fans and the city of London. This is so humiliating in a closely contested Euro Cup in Wembley, London"
input_str=word_tokenize(input_str)
for word in input_str:
    print(lemma.lemmatize(word))
# Out:
# English
# fan
# were
# really
# rude
# and
# disrespectful
# to
# Italian
# fan
# and
# the
# city
# of
# London
# .
# This
# is
# so
# humiliating
# in
# a
# closely
# contested
# Euro
# Cup
# in
# Wembley
# ,
# London

# %% [markdown]
# Object Standardization
#
# Text data often contains words or phrases which are not present in any standard lexical dictionaries. These pieces are not recognized by search engines and models.

# %%
lookup_dict = {'rt':'Retweet', 'dm':'direct message', "awsm" : "awesome", "luv" :"love", "@":"at", "info":"information"}
def lookup_words(input_text):
    words = input_text.split()
    new_words = []
    for word in words:
        if word.lower() in lookup_dict:
            word = lookup_dict[word.lower()]
        new_words.append(word)
        new_text = " ".join(new_words)
    return new_text

print(lookup_words("RT We are going to CCD @ MG Road!! dm for more info !!"))
# Out:
# Retweet We are going to CCD at MG Road!! direct message for more information !!

# %%
{"IEEE 802.11ac": "Wireless protocol for internet router and network cards"}
# Out:
# {'IEEE 802.11ac': 'Wireless protocol for internet router and network cards'}
